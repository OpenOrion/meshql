# %% [markdown]
# # Meshing

# %% [markdown]
# ## Inviscid Wedge
# ![Inviscid Wedge](../assets/inviscid_wedge.png)
#
# https://su2code.github.io/tutorials/Inviscid_Wedge/

# %%
import cadquery as cq
from meshql import GeometryQL, Split


with GeometryQL.gmsh() as geo:
    geo = (
        geo
        .load((
            cq.Workplane("XY")
            .polyline([(0, 1), (1.5, 1), (1.5, 0.2), (0.5, 0), (0, 0)])
            .close()
            ), 
            preprocess= (Split, lambda split: (
                split.from_lines(((0.5,0), (0.5,1)))
            ))
        )
        .setTransfiniteAuto(500)

        .edges(indices=[0,1,3,4,5,6])
        .addPhysicalGroup(["inlet", "lower", "upper", "lower", "outlet", "upper"])
        .end()

        .generate()
        .show("mesh")
    )
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 50%] Meshing curve 4 (Line)
# Info    : [ 60%] Meshing curve 5 (Line)
# Info    : [ 80%] Meshing curve 6 (Line)
# Info    : [ 90%] Meshing curve 7 (Line)
# Info    : Done meshing 1D (Wall 0.00030475s, CPU 0.00051s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 60%] Meshing surface 2 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00298058s, CPU 0.002015s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 8.62501e-06s, CPU 7e-06s)
# Info    : 90720 nodes 91586 elements
# VBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, far=100000.0, near=0.001, position…
