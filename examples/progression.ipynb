# %% [markdown]
# # Sturctured Grid with Bump

# %%
import cadquery as cq
from meshql import GeometryQL, Split


with GeometryQL.gmsh() as geo:
    ql = (
        geo
        .load(  
            cq.Workplane("XY")
            .polyline([(0,0), (1,0), (2,0.5), (2,2), (1, 2), (0,2)])
            .close(),
            preprocess=(Split, lambda split: (
                split.from_lines(((1,0), (1,2)))
            ))
        )
        .setTransfiniteAuto(max_nodes=100)
        
        .fromTagged([f"edge/{i}" for i in [1, 2, 5, 6, 7, 4]])
        .addPhysicalGroup(["inlet", "freestream", "freestream", "outlet", "wall", "wall"])
        .end()

    
        .fromTagged(["edge/3"])
        .addBoundaryLayer(0.001)
        .end()

        .generate()
        .show("mesh")
    )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 19
#       2 from meshql import GeometryQL, Split
#       5 with GeometryQL.gmsh() as geo:
#       6     ql = (
#       7         geo
#       8         .load(
#       9             cq.Workplane("XY")
#      10             .polyline([(0,0), (1,0), (2,0.5), (2,2), (1, 2), (0,2)])
#      11             .close(),
#      12             preprocess=(Split, lambda split: (
#      13                 split.from_lines(((1,0), (1,2)))
#      14             ))
#      15         )
#      16         .setTransfiniteAuto(max_nodes=100)
#      17
#      18         .fromTagged([f"edge/{i}" for i in [1, 2, 5, 6, 7, 4]])
# ---> 19         .addPhysicalGroup(["inlet", "freestream", "freestream", "outlet", "wall", "wall"])
#      20         .end()
#      21
#      22
#      23         .fromTagged(["edge/3"])
#      24         .addBoundaryLayer(0.001)
#      25         .end()
#      26
#      27         .generate()
#      28         .show("mesh")
#      29     )
#
# File /workspaces/hypersim/meshql/meshql/gmsh/ql.py:116, in GmshGeometryQL.addPhysicalGroup(self, group)
#     114 elif isinstance(group, Sequence):
#     115     for i, group_name in enumerate(group):
# --> 116         new_group_entity = list(self.vals())[i]
#     117         self._addEntityGroup(
#     118             group_name, OrderedSet([new_group_entity]))
#     119 return self
#
# IndexError: list index out of range
