# %% [markdown]
# # Sturctured Grid with Bump

# %%
import cadquery as cq
from meshql import GeometryQL, Split


with GeometryQL.gmsh() as geo:
    ql = (
        geo
        .load(  
            cq.Workplane("XY")
            .polyline([(0,0), (1,0), (2,0.5), (2,2), (1, 2), (0,2)])
            .close(),
            on_preprocess=lambda ql: (
                Split(ql)
                .from_lines(((1,0), (1,2)))
            )
        )
        .setTransfiniteAuto(max_nodes=100)
        
        .fromTagged([f"edge/{i}" for i in [1, 2, 5, 6, 7, 4]])
        .addPhysicalGroup(["inlet", "freestream", "freestream", "outlet", "wall", "wall"])
        .end()

    
        .fromTagged(["edge/3"])
        .addBoundaryLayer(0.001)
        .end()

        .generate()
        .show("mesh")
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 25
#       2 from meshql import GeometryQL, Split
#       5 with GeometryQL.gmsh() as geo:
#       6     ql = (
#       7         geo
#       8         .load(
#       9             cq.Workplane("XY")
#      10             .polyline([(0,0), (1,0), (2,0.5), (2,2), (1, 2), (0,2)])
#      11             .close(),
#      12             on_preprocess=lambda ql: (
#      13                 Split(ql)
#      14                 .from_lines(((1,0), (1,2)))
#      15             )
#      16         )
#      17         .setTransfiniteAuto(max_nodes=100)
#      18
#      19         .fromTagged([f"edge/{i}" for i in [1, 2, 5, 6, 7, 4]])
#      20         .addPhysicalGroup(["inlet", "freestream", "freestream", "outlet", "wall", "wall"])
#      21         .end()
#      22
#      23
#      24         .fromTagged(["edge/3"])
# ---> 25         .addBoundaryLayer(0.001)
#      26         .end()
#      27
#      28         .generate()
#      29         .show("mesh")
#      30     )
#
# File /workspaces/hypersim/meshql/meshql/gmsh/ql.py:403, in GmshGeometryQL.addBoundaryLayer(self, size, ratio, num_layers, auto_recombine)
#     395 def addBoundaryLayer(
#     396     self,
#     397     size: float,
#    (...)    400     auto_recombine: bool = True,
#     401 ):
#     402     if self._ctx.is_structured:
# --> 403         self._addStructuredBoundaryLayer(
#     404             self._workplane.vals(), size, ratio)
#     405     else:
#     406         ratio = ratio or 1.0
#
# File /workspaces/hypersim/meshql/meshql/gmsh/ql.py:372, in GmshGeometryQL._addStructuredBoundaryLayer(self, cq_objs, size, ratio)
#     368 assert edge.type == "Edge", "StructuredBoundaryLayer only accepts edges"
#     370 if size:
#     371     edge_ratio = get_boundary_ratio(
# --> 372         cq_edge.Length(), size, transaction.num_elems)  # type: ignore
#     373 elif ratio:
#     374     edge_ratio = ratio
#
# AttributeError: 'NoneType' object has no attribute 'num_elems'
