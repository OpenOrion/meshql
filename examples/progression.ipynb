# %% [markdown]
# # Sturctured Grid with Bump

# %%
import cadquery as cq
from meshql import GeometryQL, Split


with GeometryQL.gmsh() as geo:
    ql = (
        geo
        .load(  
            cq.Workplane("XY")
            .polyline([(0,0), (1,0), (2,0.5), (2,2), (1, 2), (0,2)])
            .close(),
            preprocess=(Split, lambda split: (
                split.from_lines(((1,0), (1,2)))
            ))
        )
        .setTransfiniteAuto(max_nodes=100)
        
        .fromTagged([f"edge/{i}" for i in [1, 2, 5, 6, 7, 4]])
        .addPhysicalGroup(["inlet", "freestream", "freestream", "outlet", "wall", "wall"])
        .end()

    
        .fromTagged(["edge/3"])
        .addBoundaryLayer(0.001)
        .end()

        .generate()
        .show("mesh")
    )
# Out:
# Overwriting auto display for cadquery Workplane and Shape
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (TrimmedCurve)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 50%] Meshing curve 4 (Line)
# Info    : [ 60%] Meshing curve 5 (TrimmedCurve)
# Info    : [ 80%] Meshing curve 6 (Line)
# Info    : [ 90%] Meshing curve 7 (Line)
# Info    : Done meshing 1D (Wall 0.00102054s, CPU 0.001157s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 60%] Meshing surface 2 (Transfinite)
# Info    : Done meshing 2D (Wall 0.000353791s, CPU 0.000412s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.97501e-05s, CPU 2.7e-05s)
# Info    : 3952 nodes 4134 elements
# /home/vscode/miniconda3/lib/python3.12/site-packages/cadquery/selectors.py:865: PyparsingDeprecationWarning:
#
# 'parseString' deprecated - use 'parse_string'
#
# /home/vscode/miniconda3/lib/python3.12/site-packages/pyparsing/util.py:466: PyparsingDeprecationWarning:
#
# 'parseAll' argument is deprecated, use 'parse_all'
# VBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, far=100000.0, near=0.001, position…
